# %% [markdown]
# # APIs - Cumulative Lab
#
#
# ## Introduction
#
# We've seen how the Yelp API works and how to create basic visualizations using Folium. It's time to put those skills to work in order to create a working map! Taking things a step further, you'll also independently explore how to perform pagination in order to retrieve a full results set from the Yelp API.
#
# ## Objectives
#
# You will be able to:
#
# * Practice using functions to organize your code
# * Use pagination to retrieve all results from an API query
# * Practice parsing data returned from an API query
# * Practice interpreting visualizations of a dataset
# * Create maps using Folium

# %% [markdown]
# ## Your Task: Query Yelp for All Businesses in a Category and Analyze the Results
#
# ![restaurant counter with pizza](images/restaurant_counter.jpg)
#
# Photo by <a href="https://unsplash.com/@jordanmadrid?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Jordan Madrid</a> on <a href="/s/photos/pizza-restaurant?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Overview
#
# You've now worked with some API calls, but we have yet to see how to retrieve a more complete dataset in a programmatic manner. In this lab, you will write a query of businesses on Yelp, then use *pagination* to retrieve all possible results for that query. Then you will create a summary of your findings, including a Folium map of the geographic locations of those businesses.
#
# ### Technical Details
#
# Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the **API limits**. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a **maximum of 50 results per request** and defaults to 20. Furthermore, any search will be limited to a **total of 1000 results**. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retrieving 50 at a time. Processes such as these are often referred to as pagination.
#
# Also, be mindful of the **API** ***rate*** **limits**. You can only make **5000 requests per day** and are also can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use `time.sleep(n)` to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.
#
# In this lab, you will define a search and then paginate over the results to retrieve all of the results. You'll then parse these responses as a list of dictionaries (for further exploration) and create a map using Folium to visualize the results geographically.
#
# ### Requirements
#
# #### 1. Make the Initial Request
#
# Start by filling in your API key to make the initial request to the business search API. Investigate the structure of the response you get back and start figuring out how you will extract the relevant information.
#
# #### 2. Add Pagination
#
# Using loops and functions, collect the maximum number of results for your query from the API.
#
# #### 3. Perform Exploratory Analysis
#
# Interpret visualizations related to the price range, average rating, and number of reviews for all query results.
#
# #### 4. Create a Folium Map
#
# Using latitude and longitude data, plot the query results on an interactive map.

# %% [markdown]
# ## 1. Make the Initial Request
#
# ### Querying
#
# Start by making an initial request to the Yelp API. Your search must include at least 2 parameters: **term** and **location**. For example, you might search for pizza restaurants in NYC. The term and location is up to you but make the request below.
#
# Use the `requests` library ([documentation here](https://requests.readthedocs.io/en/master/user/quickstart/#make-a-request)).
#
# You'll also need an API key from Yelp. If you haven't done this already, go to the Yelp [Manage App page](https://www.yelp.com/developers/v3/manage_app) and create a new app (after making an account if you haven't already).

# %%
# Replace None with appropriate code

# Import the requests library
import requests

# Get this from the "Manage App" page. Make sure you set them
# back to None before pushing this to GitHub, since otherwise
# your credentials will be compromised
api_key = 

# These can be whatever you want! But the solution uses "pizza"
# and "New York NY" if you want to compare your work directly
term = "sushi"
location = "Brooklyn NY"

# Set up params for request
url = "https://api.yelp.com/v3/businesses/search"
headers = {
    "Authorization": "Bearer {}".format(api_key)
}
url_params = {
    "term": term.replace(" ", "+"),
    "location": location.replace(" ", "+")
}

# Make the request using requests.get, passing in
# url, headers=headers, and params=url_params
response = requests.get(url, headers=headers, params=url_params)

# Confirm we got a 200 response
response
# Out:
# <Response [200]>

# %%
# Run this cell without changes

# Get the response body in JSON format
response_json = response.json()
# View the keys
response_json.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %% [markdown]
# ### Extracting Data
#
# Now, retrieve the value associated with the `'businesses'` key, and inspect its contents.

# %%
# Replace None with appropriate code

# Retrieve the value from response_json
businesses = response.json()['businesses']

response.json()['businesses']

# View the first 2 records
businesses[:2]
# Out:
# [{'id': 'KrJ6m_TkxBAPPSNH-G7rvQ',
#   'alias': 'u-gu-brooklyn-4',
#   'name': 'U-gu',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RItjMW2Bdyhj7JuymhpMPA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/u-gu-brooklyn-4?adjust_creative=xqzpyRWN2pvhEbxg1rI0Ng&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=xqzpyRWN2pvhEbxg1rI0Ng',
#   'review_count': 151,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.69393, 'longitude': -73.96284},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '541 Myrtle Ave',
#    'address2': 'Ste B',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11205',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['541 Myrtle Ave', 'Ste B', 'Brooklyn, NY 11205']},
#   'phone': '+17188570222',
#   'display_phone': '(718) 857-0222',
#   'distance': 5028.667026572206},
#  {'id': 'fHHpSKT9u7PQBYaMW5cEkA',
#   'alias': 'trad-room-brooklyn-2',
#   'name': 'Trad Room',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/G601cUICmfD0XI3vjyE4yg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/trad-room-brooklyn-2?adjust_creative=xqzpyRWN2pvhEbxg1rI0Ng&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=xqzpyRWN2pvhEbxg1rI0Ng',
#   'review_count': 67,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.68391, 'longitude': -73.929419},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '266 Malcolm X Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11233',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['266 Malcolm X Blvd', 'Brooklyn, NY 11233']},
#   'phone': '+13472405760',
#   'display_phone': '(347) 240-5760',
#   'distance': 3610.253857721571}]

# %% [markdown]
# ### Preparing Data
#
# Write a function `prepare_data` that takes in a list of dictionaries like `businesses` and returns a copy that has been prepared for analysis:
#
# 1. The `coordinates` key-value pair has been converted into two separate key-value pairs, `latitude` and `longitude`
# 2. All other key-value pairs except for `name`, `review_count`, `rating`, and `price` have been dropped
# 3. All dictionaries missing one of the relevant keys or containing null values have been dropped
#
# In other words, the final keys for each dictionary should be `name`, `review_count`, `rating`, `price`, `latitude`, and `longitude`.
#
# Complete the function in the cell below:

# %%
# Replace None with appropriate code

def prepare_data(data_list):
    
    
    # Make a new list to hold results
    results = []
    
    for business_data in data_list:
    
        # Make a new dictionary to hold prepared data for this business
        prepared_data = {}
        
        # Extract name, review_count, rating, and price key-value pairs
        # from business_data and add to prepared_data
        # If a key is not present in business_data, add it to prepared_data
        # with an associated value of None
    
        if 'name' in business_data: 
            prepared_data['name'] = business_data['name']
        else: 
            prepared_data['name'] = 'None'
            
        if 'review_count' in business_data: 
            prepared_data['review_count'] = business_data['review_count']
        else: 
            prepared_data['review_count'] = 'None'
            
        if 'rating'in business_data: 
            prepared_data['rating'] = business_data['rating']
        else: 
            prepared_data['rating'] = 'None'
            
        if 'price'in business_data: 
             prepared_data['price'] = business_data['price']
        else: 
             prepared_data['price'] = 'None'        

        # Parse and add latitude and longitude columns
        if 'coordinates' in business_data: 
            prepared_data['latitude'] = business_data['coordinates']['latitude']
            prepared_data['longitude'] = business_data['coordinates']['longitude']
        else: 
            prepared_data['latitude'] = 'None'
            prepared_data['longitude'] = 'None'      
        
        # Add to list if all values are present
        if all(prepared_data.values()):
            results.append(prepared_data)
    
    return results
    
# Test out function
prepared_businesses = prepare_data(businesses)
prepared_businesses[:5]

##.get(key, value to return if key doesn't exist) 
## list of keys to iterate over
# Out:
# [{'name': 'U-gu',
#   'review_count': 151,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.69393,
#   'longitude': -73.96284},
#  {'name': 'Trad Room',
#   'review_count': 67,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.68391,
#   'longitude': -73.929419},
#  {'name': 'Bushniwa',
#   'review_count': 215,
#   'rating': 4.5,
#   'price': 'None',
#   'latitude': 40.70397,
#   'longitude': -73.93344},
#  {'name': 'KanaHashi',
#   'review_count': 168,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.73263,
#   'longitude': -73.95482},
#  {'name': 'Uotora',
#   'review_count': 107,
#   'rating': 4.5,
#   'price': '$$$$',
#   'latitude': 40.676369,
#   'longitude': -73.950486}]

# %% [markdown]
# Check that your function created the correct keys:

# %%
# Run this cell without changes

assert sorted(list(prepared_businesses[0].keys())) == ['latitude', 'longitude', 'name', 'price', 'rating', 'review_count']

# %% [markdown]
# The following code will differ depending on your query, but we expect there to be 20 businesses in the original list, and potentially fewer in the prepared list (if any of them were missing data):

# %%
# Run this cell without changes
print("Original:", len(businesses))
print("Prepared:", len(prepared_businesses))
# Out:
# Original: 20
# Prepared: 20

# %% [markdown]
# Great! We will reuse this function once we have retrieved the full dataset.

# %% [markdown]
# ## 2. Add Pagination
#
# Now that you are able to extract information from one page of the response, let's figure out how to request as many pages as possible.
#
# ### Determining the Total
#
# Depending on the number of total results for your query, you will either retrieve all of the results, or just the first 1000 (if there are more than 1000 total).
#
# We can find the total number of results using the `"total"` key:

# %%
# Run this cell without changes
response_json["total"]
# Out:
# 240

# %% [markdown]
# (This is specific to the implementation of the Yelp API. Some APIs will just tell you that there are more pages, or will tell you the number of pages total, rather than the total number of results. If you're not sure, always check the documentation.)
#
# In the cell below, assign the variable `total` to either the value shown above (if it is less than 1000), or 1000.

# %%
# Replace None with appropriate code
total = 240

# %% [markdown]
# ### Calculating the Offsets
#
# The documentation states in the parameters section:
#
# > **Name**: `limit`, **Type:** int, **Description:** Optional. Number of business results to return. By default, it will return 20. Maximum is 50.
#
# > **Name**: `offset`, **Type:** int, **Description:** Optional. Offset the list of returned business results by this amount.
#
# So, to get the most results with the fewest API calls we want to set a limit of 50 every time. If, say, we wanted to get 210 total results, that would mean:
#
# 1. Offset of `0` (first 50 records)
# 2. Offset of `50` (second 50 records)
# 3. Offset of `100` (third 50 records)
# 4. Offset of `150` (fourth 50 records)
# 5. Offset of `200` (final 10 records)
#
# In the cell below, create a function `get_offsets` that takes in a total and returns a list of offsets for that total. You can assume that there is a limit of 50 every time.
#
# *Hint: you can use `range` ([documentation here](https://docs.python.org/3.3/library/stdtypes.html?highlight=range#range)) to do this in one line of code. Just make the returned result is a list.*

# %%
# Replace None with appropriate code
def get_offsets(total):
#     offset=[]
    offset = list(range(0, total, 50))
#             offset.append(number)
    return offset
 
get_offsets(total)
# Out:
# [0, 50, 100, 150, 200]

# %% [markdown]
# Check that your function works below:

# %%
# Run this cell without changes

assert get_offsets(200) == [0, 50, 100, 150]
assert get_offsets(210) == [0, 50, 100, 150, 200]

# %% [markdown]
# ### Putting It All Together
#
# Recall that the following variable has already been declared for you:

# %%
# Run this cell without changes
url_params
# Out:
# {'term': 'sushi', 'location': 'Brooklyn+NY'}

# %% [markdown]
# We'll go ahead and also specify that the limit should be 50 every time:

# %%
# Run this cell without changes
url_params["limit"] = 50

# %% [markdown]
# In order to modify the offset, you'll need to add it to `url_params` with the key `"offset"` and whatever value is needed.
#
# In the cell below, write code that:
#
# * Creates an empty list for the full prepared dataset
# * Loops over all of the offsets from `get_offsets` and makes an API call each time with the specified offset
# * Calls `prepare_data` to get a cleaned version of the result of each API call
# * Extends the full prepared dataset list with each query's prepared dataset

# %%
# Replace None with appropriate code

# Create an empty list for the full prepared dataset
full_dataset = []

for offset in get_offsets(total):
    print(offset)
    
    # Add or update the "offset" key-value pair in url_params
    url_params['offset'] = offset
    
    # Make the query and get the response
    response = requests.get(url, headers=headers, params=url_params)
    
    # Get the response body in JSON format
    response_json = response.json()
    try: 
        # Get the list of businesses from the response_json
        businesses = response_json['businesses']

        # Call the prepare_data function to get a list of processed data
        prepared_businesses = prepare_data(businesses)

        # Extend full_dataset with this list (don't append, or you'll get
        # a list of lists instead of a flat list)
        full_dataset.extend(prepared_businesses)
    except: print(response_json)
# Check the length of the full dataset. It will be up to `total`,
# potentially less if there were missing values
len(full_dataset)
# Out:
# 0
# 50
# 100
# 150
# 200
# {'error': {'code': 'INTERNAL_ERROR', 'description': 'Something went wrong internally, please try again later.'}}
# 200

# %% [markdown]
# This code may take up to a few minutes to run.
#
# If you get an error trying to get the response body in JSON format, try adding `time.sleep(1)` right after the `requests.get` line, so your code will sleep for 1 second between each API call.

# %% [markdown]
# ## 3. Perform Exploratory Analysis
#
# Take the businesses from the previous question and do an initial exploratory analysis. We have provided some plots for you to interpret:

# %%
# Run this cell without changes
from collections import Counter
import matplotlib.pyplot as plt
# %matplotlib inline

fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(16, 5), facecolor = "white")

# Plot distribution of number of reviews
all_review_counts = [x["review_count"] for x in full_dataset]
ax1.hist(all_review_counts)
ax1.set_title("Review Count Distribution")
ax1.set_xlabel("Number of Reviews")
ax1.set_ylabel("Number of Businesses")

# Plot rating distribution
all_ratings = [x["rating"] for x in full_dataset]
rating_counter = Counter(all_ratings)
rating_keys = sorted(rating_counter.keys())
ax2.bar(rating_keys, [rating_counter[key] for key in rating_keys])
ax2.set_title("Rating Distribution")
ax2.set_xlabel("Rating")
ax2.set_ylabel("Number of Businesses")

# Plot price distribution
all_prices = [x["price"].replace("$", r"\$") for x in full_dataset]
price_counter = Counter(all_prices)
price_keys = sorted(price_counter.keys())
ax3.bar(price_keys, [price_counter[key] for key in price_keys])
ax3.set_title("Price Distribution")
ax3.set_xlabel("Price Category")
ax3.set_ylabel("Number of Businesses");

# %% [markdown]
# Describe the distributions displayed above and interpret them in the context of your query. (Your answer may differ from the solution branch depending on your query.)

# %%
# Replace None with appropriate text
"""
The vast majority of sushi restuarants in Brooklyn, New York have less than 1,000 reviews and of those reviews, most 
sushi restuarants have less than 500. Additionally, there's a heavy lean for buisnesses to have a rating between 3.5 and 4.5
stars. However, the strongest trend is for sushi restaurants in Brooklyn, New York to have the $$ price category. 
"""

# %% [markdown]
# In the cell below, we also plot the rating distributions by price. In this setup, a price of one dollar sign is "lower price" and everything else is "higher price".

# %%
# Run this cell without changes

higher_price = []
lower_price = []
for row in full_dataset:
    if row["price"] == "$":
        lower_price.append(row["rating"])
    else:
        higher_price.append(row["rating"])
        
fig, ax = plt.subplots(facecolor = "white")

ax.hist([higher_price, lower_price], label=["higher price", "lower price"], density=True)

ax.legend();

# %% [markdown]
# Is a higher price associated with a higher rating? (No need for any additional math/statistics, just interpret what you see in the plot.)

# %%
# Replace None with appropriate text
"""
In the case of sushi restaurants in Brooklyn, New York--price is absolutely a factor in how well the restaurant is rated on 
Yelp. In between 3.5 and 4.0 stars, we see the shift from a majority of reviews being lower priced to higher priced. This 
reflects that in the case of sushi, customers are expecting a luxery experience (which makes hygenic sense.)
"""

# %% [markdown]
# Finally, let's look at ratings vs. review counts:

# %%
# Run this cell without changes
fig, ax = plt.subplots(figsize=(16,5), facecolor = "white")

ax.scatter(all_review_counts, all_ratings, alpha=0.2)
ax.set_xlabel("Number of Reviews")
ax.set_ylabel("Rating")
# "zoom in" to a subset of review counts
ax.set_xlim(left=0, right=1000);

# %% [markdown]
# Is a higher number of reviews associated with a higher rating?

# %%
# Replace None with appropriate text
"""
A higher number of reviews is associated with reviews that fell inbetween 4.0 and 4.5 stars, with a skew towards 4.0. 
"""

# %% [markdown]
# ## 4. Create a Folium Map
#
# Make a map using Folium of the businesses you retrieved. Be sure to also add popups to the markers giving some basic information such as name, rating and price.
#
# You can center the map around the latitude and longitude of the first item in `full_dataset`.

# %%
full_dataset
# Out:
# [{'name': 'U-gu',
#   'review_count': 151,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.69393,
#   'longitude': -73.96284},
#  {'name': 'Trad Room',
#   'review_count': 67,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.68391,
#   'longitude': -73.929419},
#  {'name': 'Bushniwa',
#   'review_count': 215,
#   'rating': 4.5,
#   'price': 'None',
#   'latitude': 40.70397,
#   'longitude': -73.93344},
#  {'name': 'KanaHashi',
#   'review_count': 168,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.73263,
#   'longitude': -73.95482},
#  {'name': 'Uotora',
#   'review_count': 107,
#   'rating': 4.5,
#   'price': '$$$$',
#   'latitude': 40.676369,
#   'longitude': -73.950486},
#  {'name': 'Omakase Sushi By Hiro',
#   'review_count': 25,
#   'rating': 4.5,
#   'price': 'None',
#   'latitude': 40.587619,
#   'longitude': -73.955441},
#  {'name': 'Ako',
#   'review_count': 438,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7168599,
#   'longitude': -73.95845},
#  {'name': 'Oita Nyc',
#   'review_count': 276,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.675012,
#   'longitude': -73.976204},
#  {'name': 'Gen',
#   'review_count': 282,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.677639,
#   'longitude': -73.963485},
#  {'name': 'Ki Sushi',
#   'review_count': 213,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6784417729132,
#   'longitude': -73.9734394269355},
#  {'name': 'Silver Rice',
#   'review_count': 300,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6742123562615,
#   'longitude': -73.9568891376257},
#  {'name': 'Silver Rice',
#   'review_count': 100,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6597410822446,
#   'longitude': -73.9604239538312},
#  {'name': 'Sushi Yashin',
#   'review_count': 217,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6708328473989,
#   'longitude': -73.9847132950057},
#  {'name': 'Amami Bar and Restaurant',
#   'review_count': 187,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.723548,
#   'longitude': -73.952194},
#  {'name': 'Slow Loris',
#   'review_count': 129,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6601311,
#   'longitude': -73.9607934},
#  {'name': 'Sushi Hana',
#   'review_count': 121,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.620906,
#   'longitude': -74.025741},
#  {'name': 'Wasan Brooklyn',
#   'review_count': 239,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6812605,
#   'longitude': -73.9768418},
#  {'name': 'Ume Williamsburg',
#   'review_count': 265,
#   'rating': 4.0,
#   'price': '$$$$',
#   'latitude': 40.71657,
#   'longitude': -73.96559},
#  {'name': 'Arashi Sushi',
#   'review_count': 48,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.65603,
#   'longitude': -73.91544},
#  {'name': 'Okonomi',
#   'review_count': 467,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.712622,
#   'longitude': -73.9487843},
#  {'name': 'Suzume',
#   'review_count': 327,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7131652,
#   'longitude': -73.9494479},
#  {'name': 'Daigo Sushi Roll Bar',
#   'review_count': 56,
#   'rating': 4.5,
#   'price': 'None',
#   'latitude': 40.676541,
#   'longitude': -73.98445},
#  {'name': 'Buntopia',
#   'review_count': 328,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.69598,
#   'longitude': -73.93398},
#  {'name': 'Akaru Sushi',
#   'review_count': 206,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7025074325866,
#   'longitude': -73.9161351568057},
#  {'name': 'MOMO Hibachi Steak House & Bar',
#   'review_count': 235,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.583724,
#   'longitude': -73.949334},
#  {'name': 'Mirakuya - Brooklyn',
#   'review_count': 59,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7004883125668,
#   'longitude': -73.9435394480824},
#  {'name': 'Sushi Lin',
#   'review_count': 286,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.677786,
#   'longitude': -73.972591},
#  {'name': 'Musashi Asian Cuisine',
#   'review_count': 169,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7111358642578,
#   'longitude': -73.9514236450195},
#  {'name': 'Inaka Asian Cuisine',
#   'review_count': 249,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.679565,
#   'longitude': -73.967819},
#  {'name': 'Fushimi Williamsburg',
#   'review_count': 710,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.718827,
#   'longitude': -73.954131},
#  {'name': 'Mura',
#   'review_count': 187,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.671501,
#   'longitude': -73.984717},
#  {'name': 'Momo Sushi Shack',
#   'review_count': 656,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70512,
#   'longitude': -73.933463},
#  {'name': 'Salt + Charcoal',
#   'review_count': 592,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.71453,
#   'longitude': -73.9613511},
#  {'name': 'Akino',
#   'review_count': 919,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.741236,
#   'longitude': -73.881306},
#  {'name': 'Yoshi Japanese cuisine',
#   'review_count': 100,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.61572,
#   'longitude': -73.9180499},
#  {'name': 'Sumi Sushi',
#   'review_count': 138,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.679178,
#   'longitude': -73.973522},
#  {'name': 'Sarku Japan',
#   'review_count': 35,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.650745,
#   'longitude': -73.889875},
#  {'name': 'Sushi King',
#   'review_count': 31,
#   'rating': 4.0,
#   'price': 'None',
#   'latitude': 40.698801,
#   'longitude': -73.917241},
#  {'name': 'Samurai Mama',
#   'review_count': 612,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7140208838114,
#   'longitude': -73.960325717926},
#  {'name': 'Sushi Uesugi',
#   'review_count': 45,
#   'rating': 4.5,
#   'price': 'None',
#   'latitude': 40.6560432255486,
#   'longitude': -74.0064066279496},
#  {'name': 'Komorebi Full House',
#   'review_count': 54,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.630169,
#   'longitude': -74.004041},
#  {'name': 'Tsukimi',
#   'review_count': 31,
#   'rating': 5.0,
#   'price': 'None',
#   'latitude': 40.72908,
#   'longitude': -73.98541},
#  {'name': 'To Date Japanese Food',
#   'review_count': 25,
#   'rating': 4.5,
#   'price': 'None',
#   'latitude': 40.637337,
#   'longitude': -74.008481},
#  {'name': 'Minami Lounge',
#   'review_count': 66,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70944,
#   'longitude': -73.95566},
#  {'name': 'Pine Tree Organics',
#   'review_count': 71,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.673013,
#   'longitude': -73.957391},
#  {'name': 'Za-Ya',
#   'review_count': 12,
#   'rating': 5.0,
#   'price': 'None',
#   'latitude': 40.708065,
#   'longitude': -73.920499},
#  {'name': 'Geido',
#   'review_count': 335,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.67792,
#   'longitude': -73.97266},
#  {'name': 'Daigo Handroll Bar',
#   'review_count': 93,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.690884,
#   'longitude': -73.982863},
#  {'name': '1 OR 8',
#   'review_count': 417,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.6896859,
#   'longitude': -73.9703551},
#  {'name': 'E sushi 2',
#   'review_count': 153,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.58884,
#   'longitude': -73.9492099},
#  {'name': 'KOMA Sushi',
#   'review_count': 8,
#   'rating': 5.0,
#   'price': 'None',
#   'latitude': 40.61808030483254,
#   'longitude': -73.95847718711664},
#  {'name': 'Ten Japanese Cuisine',
#   'review_count': 256,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6634864807129,
#   'longitude': -73.984748840332},
#  {'name': 'Kiku Asian Bistro',
#   'review_count': 266,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.67754,
#   'longitude': -73.97956},
#  {'name': 'Chuko',
#   'review_count': 1075,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.680784,
#   'longitude': -73.967455},
#  {'name': 'SUGARFISH  by sushi nozawa - Midtown West',
#   'review_count': 74,
#   'rating': 4.0,
#   'price': 'None',
#   'latitude': 40.764976,
#   'longitude': -73.981655},
#  {'name': 'Noribar',
#   'review_count': 9,
#   'rating': 3.5,
#   'price': 'None',
#   'latitude': 40.667931,
#   'longitude': -73.942498},
#  {'name': 'Sai',
#   'review_count': 251,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.73012,
#   'longitude': -73.8636},
#  {'name': 'Sushi Katsuei',
#   'review_count': 473,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.6707147,
#   'longitude': -73.9785903},
#  {'name': 'Rakuzen',
#   'review_count': 257,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.63112,
#   'longitude': -74.00903},
#  {'name': 'Taiki',
#   'review_count': 84,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.6845433545275,
#   'longitude': -73.9837775425761},
#  {'name': 'Sushi Tatsu III',
#   'review_count': 151,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.657581,
#   'longitude': -73.960658},
#  {'name': 'Samurai Fusion Sushi',
#   'review_count': 158,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.608551,
#   'longitude': -74.004348},
#  {'name': 'Sakura Tokyo',
#   'review_count': 229,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.6779,
#   'longitude': -73.94989},
#  {'name': 'Kyoto',
#   'review_count': 233,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6877593994141,
#   'longitude': -73.989501953125},
#  {'name': 'SUGARFISH by sushi nozawa',
#   'review_count': 895,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.73901,
#   'longitude': -73.98882},
#  {'name': 'Hibino',
#   'review_count': 406,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.69017,
#   'longitude': -73.99637},
#  {'name': 'Saketumi Asian Bistro',
#   'review_count': 157,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.69480157691335,
#   'longitude': -73.99473861016685},
#  {'name': 'Raku',
#   'review_count': 1206,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7264988089246,
#   'longitude': -73.9866526052356},
#  {'name': 'Asea Fusion',
#   'review_count': 283,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.64588,
#   'longitude': -73.99915},
#  {'name': 'Izakaya MEW',
#   'review_count': 2459,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.750148,
#   'longitude': -73.9863203465939},
#  {'name': 'Koto Sushi',
#   'review_count': 166,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.680029,
#   'longitude': -73.974163},
#  {'name': 'Ki Sushi',
#   'review_count': 723,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.68764,
#   'longitude': -73.9901},
#  {'name': "O'Sake Japanese Restaurant",
#   'review_count': 76,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.580977,
#   'longitude': -73.838259},
#  {'name': 'Inaka Japanese Fusion',
#   'review_count': 221,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6252403259277,
#   'longitude': -74.030647277832},
#  {'name': 'Chiko',
#   'review_count': 43,
#   'rating': 5.0,
#   'price': 'None',
#   'latitude': 40.7319,
#   'longitude': -73.95422},
#  {'name': 'Sushi Yu',
#   'review_count': 136,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.660354,
#   'longitude': -73.980682},
#  {'name': 'Sushi Gallery',
#   'review_count': 140,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6975970682387,
#   'longitude': -73.9933660828876},
#  {'name': 'Sushi & Noodles',
#   'review_count': 157,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70347,
#   'longitude': -73.92577},
#  {'name': 'Rule of Thirds',
#   'review_count': 121,
#   'rating': 4.0,
#   'price': 'None',
#   'latitude': 40.7246328,
#   'longitude': -73.9551096},
#  {'name': 'Asia Harbor',
#   'review_count': 118,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.643948,
#   'longitude': -73.9763473},
#  {'name': 'Kiku Sushi',
#   'review_count': 152,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.66278,
#   'longitude': -73.98483},
#  {'name': 'Bozu',
#   'review_count': 844,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7129,
#   'longitude': -73.95749},
#  {'name': 'Sushi K Bar',
#   'review_count': 32,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.6942529,
#   'longitude': -73.9560939},
#  {'name': 'Kiku Sushi',
#   'review_count': 83,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.6658058166504,
#   'longitude': -73.9821548461914},
#  {'name': 'Ninja 86 Sushi',
#   'review_count': 106,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6006799,
#   'longitude': -73.99208},
#  {'name': 'Sushi Lab',
#   'review_count': 365,
#   'rating': 4.5,
#   'price': 'None',
#   'latitude': 40.758417,
#   'longitude': -73.983301},
#  {'name': 'Sushi Spot',
#   'review_count': 38,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.6645584,
#   'longitude': -73.9426699},
#  {'name': 'Shalom Japan',
#   'review_count': 304,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7091679,
#   'longitude': -73.9558028},
#  {'name': 'Karasu',
#   'review_count': 102,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.689411,
#   'longitude': -73.973256},
#  {'name': 'Neta Shari',
#   'review_count': 54,
#   'rating': 4.5,
#   'price': '$$$$',
#   'latitude': 40.608116,
#   'longitude': -74.004501},
#  {'name': 'Samurai Papa BS',
#   'review_count': 171,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.68981,
#   'longitude': -73.95101},
#  {'name': 'Sapporo',
#   'review_count': 113,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.629027,
#   'longitude': -74.029126},
#  {'name': 'DOMODOMO - New York',
#   'review_count': 1264,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7280299,
#   'longitude': -74.00167},
#  {'name': 'Soku 1546',
#   'review_count': 17,
#   'rating': 4.0,
#   'price': 'None',
#   'latitude': 40.69938,
#   'longitude': -73.91177},
#  {'name': 'New Mizu Sushi',
#   'review_count': 199,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7283,
#   'longitude': -73.98538},
#  {'name': 'One Two Free Sushi',
#   'review_count': 36,
#   'rating': 3.5,
#   'price': 'None',
#   'latitude': 40.63812,
#   'longitude': -73.97584},
#  {'name': 'Kura Revolving Sushi Bar',
#   'review_count': 300,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.85622,
#   'longitude': -73.96783},
#  {'name': 'Ninja Japan Teriyaki & Sushi',
#   'review_count': 29,
#   'rating': 3.5,
#   'price': 'None',
#   'latitude': 40.64988,
#   'longitude': -73.96146},
#  {'name': 'Aburi Sushi Bar',
#   'review_count': 146,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.712052,
#   'longitude': -73.9424949},
#  {'name': 'Sushi Tatsu',
#   'review_count': 185,
#   'rating': 2.5,
#   'price': '$$',
#   'latitude': 40.677695,
#   'longitude': -73.9553284},
#  {'name': 'Masago Bistro',
#   'review_count': 136,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.6723857,
#   'longitude': -73.950524},
#  {'name': 'That Sushi Spot',
#   'review_count': 18,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.6247304,
#   'longitude': -73.9466499},
#  {'name': 'Jpan',
#   'review_count': 318,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.673599,
#   'longitude': -73.982254},
#  {'name': 'SUGARFISH by sushi nozawa',
#   'review_count': 199,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72511,
#   'longitude': -74.00358},
#  {'name': 'Natto Hibachi & Sushi',
#   'review_count': 43,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.6737814,
#   'longitude': -73.9827748},
#  {'name': 'Kuma NYC',
#   'review_count': 56,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.699183,
#   'longitude': -73.91304},
#  {'name': 'Sushi Kai',
#   'review_count': 102,
#   'rating': 4.5,
#   'price': '$$$$',
#   'latitude': 40.728498,
#   'longitude': -73.98615},
#  {'name': 'Douska',
#   'review_count': 132,
#   'rating': 4.5,
#   'price': 'None',
#   'latitude': 40.7191369,
#   'longitude': -73.9908998},
#  {'name': 'Kimoto Rooftop',
#   'review_count': 608,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.6915156530047,
#   'longitude': -73.9846554},
#  {'name': 'Sakura Japanese Restaurant',
#   'review_count': 33,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.5800846,
#   'longitude': -73.837562},
#  {'name': 'Bondi',
#   'review_count': 27,
#   'rating': 4.0,
#   'price': 'None',
#   'latitude': 40.72121,
#   'longitude': -73.99628},
#  {'name': 'Hayashi',
#   'review_count': 185,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.590482,
#   'longitude': -73.94938},
#  {'name': 'Bondi Sushi',
#   'review_count': 11,
#   'rating': 3.5,
#   'price': 'None',
#   'latitude': 40.697404,
#   'longitude': -73.970353},
#  {'name': 'Yamashiro',
#   'review_count': 147,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.69326,
#   'longitude': -73.9666},
#  {'name': 'Nagoya Sushi',
#   'review_count': 243,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.61052,
#   'longitude': -73.954472},
#  {'name': 'Sushi By M',
#   'review_count': 657,
#   'rating': 4.5,
#   'price': '$$$$',
#   'latitude': 40.72659,
#   'longitude': -73.98873},
#  {'name': 'Happy Canteen',
#   'review_count': 8,
#   'rating': 4.5,
#   'price': 'None',
#   'latitude': 40.5993,
#   'longitude': -73.95334},
#  {'name': 'Dock Asian Eatery',
#   'review_count': 167,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70628,
#   'longitude': -73.92274},
#  {'name': 'Matsuri',
#   'review_count': 166,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7458357,
#   'longitude': -73.9035436},
#  {'name': 'Wasabi Sushi',
#   'review_count': 153,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.59965,
#   'longitude': -73.98949},
#  {'name': 'Sushi On Me',
#   'review_count': 96,
#   'rating': 5.0,
#   'price': '$$$$',
#   'latitude': 40.746444,
#   'longitude': -73.893947},
#  {'name': 'Osakana',
#   'review_count': 63,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.71224,
#   'longitude': -73.94376},
#  {'name': 'Usagi NY',
#   'review_count': 68,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70383,
#   'longitude': -73.98691},
#  {'name': 'Natto Hibachi & Sushi',
#   'review_count': 154,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.67374,
#   'longitude': -73.98269},
#  {'name': 'PokéBowl Station',
#   'review_count': 99,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.68114,
#   'longitude': -73.97495},
#  {'name': 'Hiroto Japanese Restaurant',
#   'review_count': 61,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.6804182,
#   'longitude': -73.9775044},
#  {'name': 'RYUJIN',
#   'review_count': 309,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.711178187852,
#   'longitude': -73.9506256676857},
#  {'name': 'Pokébāb',
#   'review_count': 177,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.71683,
#   'longitude': -73.95866},
#  {'name': 'Aura Cocina',
#   'review_count': 61,
#   'rating': 4.0,
#   'price': 'None',
#   'latitude': 40.70896,
#   'longitude': -73.93514},
#  {'name': 'Sushi Nakazawa',
#   'review_count': 1498,
#   'rating': 4.5,
#   'price': '$$$$',
#   'latitude': 40.7317465228689,
#   'longitude': -74.0045493828034},
#  {'name': 'Yamato Restaurant',
#   'review_count': 274,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.67192,
#   'longitude': -73.97758},
#  {'name': 'Wasan Brooklyn Sushi and Udon',
#   'review_count': 3,
#   'rating': 4.5,
#   'price': 'None',
#   'latitude': 40.6814,
#   'longitude': -73.97706},
#  {'name': 'Kaoru',
#   'review_count': 406,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.75202,
#   'longitude': -73.96977},
#  {'name': 'Murasaki',
#   'review_count': 239,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7457764869508,
#   'longitude': -73.9532554683031},
#  {'name': 'Ootoya Times Square',
#   'review_count': 972,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75487,
#   'longitude': -73.98599},
#  {'name': 'I Sushi',
#   'review_count': 65,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.70035,
#   'longitude': -73.89827},
#  {'name': 'Sapporo Ichiban',
#   'review_count': 266,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.723678,
#   'longitude': -73.950462},
#  {'name': 'Tenzan',
#   'review_count': 312,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.6151355763058,
#   'longitude': -73.9939702657333},
#  {'name': 'Wiki Wiki',
#   'review_count': 26,
#   'rating': 4.0,
#   'price': 'None',
#   'latitude': 40.690726,
#   'longitude': -73.983124},
#  {'name': 'Shinn East',
#   'review_count': 84,
#   'rating': 4.5,
#   'price': 'None',
#   'latitude': 40.7265202,
#   'longitude': -73.98429},
#  {'name': 'Kami Asian Restaurant',
#   'review_count': 75,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.6761873680902,
#   'longitude': -73.9714907474522},
#  {'name': 'Longevousjoy',
#   'review_count': 319,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.61312,
#   'longitude': -73.98246},
#  {'name': 'Umi Sushi',
#   'review_count': 697,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7261983305216,
#   'longitude': -73.790670633316},
#  {'name': 'Shobu Sushi & Grill',
#   'review_count': 208,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.61582,
#   'longitude': -74.03072},
#  {'name': 'Sushi Time',
#   'review_count': 537,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7185591,
#   'longitude': -73.841229},
#  {'name': 'Masuta Japanese Fusion - Mitoushi',
#   'review_count': 292,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.58563,
#   'longitude': -73.95181},
#  {'name': 'Ozu',
#   'review_count': 265,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6974732130766,
#   'longitude': -73.9932652562857},
#  {'name': 'Sake kawa',
#   'review_count': 150,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7563,
#   'longitude': -73.92855},
#  {'name': 'Maya Congee Cafe',
#   'review_count': 115,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.68719,
#   'longitude': -73.944167},
#  {'name': 'Ootoya Chelsea',
#   'review_count': 1429,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.738721,
#   'longitude': -73.99279},
#  {'name': 'KazuNori  | The Original Hand Roll Bar',
#   'review_count': 1095,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.74519,
#   'longitude': -73.98824},
#  {'name': 'Frenasia',
#   'review_count': 253,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.651392,
#   'longitude': -73.837518},
#  {'name': 'Sushi Factory',
#   'review_count': 99,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.6418518141296,
#   'longitude': -74.0038870071483},
#  {'name': 'Hana Asian Bistro',
#   'review_count': 223,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6699939531997,
#   'longitude': -73.8424712286242},
#  {'name': 'Chikurin',
#   'review_count': 342,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.5995,
#   'longitude': -73.99011},
#  {'name': 'Blue Ribbon Sushi',
#   'review_count': 1127,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72612,
#   'longitude': -74.0025299},
#  {'name': 'Momoya',
#   'review_count': 711,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7426255196333,
#   'longitude': -73.9966481924057},
#  {'name': 'Sake Sushi',
#   'review_count': 185,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.64379,
#   'longitude': -73.976709},
#  {'name': 'Hagane',
#   'review_count': 147,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.65558,
#   'longitude': -73.8394},
#  {'name': 'Sushi Daizen',
#   'review_count': 130,
#   'rating': 4.5,
#   'price': '$$$$',
#   'latitude': 40.74445,
#   'longitude': -73.9538199},
#  {'name': 'Chikurin',
#   'review_count': 225,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.61875,
#   'longitude': -73.95484},
#  {'name': 'Sisters Sushi House',
#   'review_count': 12,
#   'rating': 4.5,
#   'price': 'None',
#   'latitude': 40.649248,
#   'longitude': -74.006368},
#  {'name': 'CZEN',
#   'review_count': 107,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.6324824894253,
#   'longitude': -73.9337566183575},
#  {'name': 'Nobu Fifty Seven',
#   'review_count': 1281,
#   'rating': 4.0,
#   'price': '$$$$',
#   'latitude': 40.7636210840864,
#   'longitude': -73.9765048613641},
#  {'name': 'Sushi Seki',
#   'review_count': 515,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.761918,
#   'longitude': -73.960536},
#  {'name': 'Sushi Lab Rooftop NYC',
#   'review_count': 250,
#   'rating': 4.0,
#   'price': 'None',
#   'latitude': 40.758489034780425,
#   'longitude': -73.98320701370044},
#  {'name': 'Sushi D',
#   'review_count': 135,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.6896898,
#   'longitude': -73.9713079},
#  {'name': 'Iron Chef House',
#   'review_count': 425,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.69722956441029,
#   'longitude': -73.99262170000003},
#  {'name': 'Mikawa Japanese Fusion',
#   'review_count': 17,
#   'rating': 5.0,
#   'price': 'None',
#   'latitude': 40.631832,
#   'longitude': -74.027361},
#  {'name': 'Sake Sushi',
#   'review_count': 753,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.600102,
#   'longitude': -73.990238},
#  {'name': 'Kashi Japanese - Rockville Centre',
#   'review_count': 506,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6572,
#   'longitude': -73.64652},
#  {'name': 'Omakase By Korami',
#   'review_count': 120,
#   'rating': 5.0,
#   'price': '$$$$',
#   'latitude': 40.763503307884655,
#   'longitude': -73.989323},
#  {'name': 'G Sushi',
#   'review_count': 6,
#   'rating': 4.0,
#   'price': 'None',
#   'latitude': 40.63425,
#   'longitude': -74.02648},
#  {'name': 'Kobeyaki',
#   'review_count': 557,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7462138,
#   'longitude': -73.99388},
#  {'name': 'Kimura',
#   'review_count': 137,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.728995,
#   'longitude': -73.988279},
#  {'name': 'Sushi 456',
#   'review_count': 20,
#   'rating': 5.0,
#   'price': 'None',
#   'latitude': 40.7313524,
#   'longitude': -74.0065048},
#  {'name': 'Kissaki Sushi',
#   'review_count': 41,
#   'rating': 4.0,
#   'price': 'None',
#   'latitude': 40.778571,
#   'longitude': -73.978209},
#  {'name': 'Ise Restaurant',
#   'review_count': 515,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7291024,
#   'longitude': -73.9900618},
#  {'name': 'Blue Ribbon Sushi Bar & Grill - New York',
#   'review_count': 772,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7674948014194,
#   'longitude': -73.9831978922043},
#  {'name': 'Wasabi Steak and Sushi',
#   'review_count': 9,
#   'rating': 4.5,
#   'price': 'None',
#   'latitude': 40.64381,
#   'longitude': -74.07618},
#  {'name': 'Noribar',
#   'review_count': 25,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.6320159,
#   'longitude': -73.994917},
#  {'name': 'SHI',
#   'review_count': 856,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.74599336793073,
#   'longitude': -73.957094},
#  {'name': 'WAZA Sushi & Ramen',
#   'review_count': 179,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.69359,
#   'longitude': -73.9657299},
#  {'name': 'Kura',
#   'review_count': 495,
#   'rating': 4.5,
#   'price': '$$$$',
#   'latitude': 40.726709,
#   'longitude': -73.9835794},
#  {'name': 'Sakura 7',
#   'review_count': 140,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7240570459862,
#   'longitude': -73.8987931830836},
#  {'name': 'Raku',
#   'review_count': 543,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72728,
#   'longitude': -74.00252},
#  {'name': 'Sushi Meshuga',
#   'review_count': 67,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.6098799,
#   'longitude': -73.95639},
#  {'name': 'Hatsuhana Sushi Restaurant',
#   'review_count': 1388,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.75703,
#   'longitude': -73.97692},
#  {'name': 'Sushi Tokyo',
#   'review_count': 131,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.6060865018953,
#   'longitude': -73.9657768732403},
#  {'name': 'Saka Sushi & Asian Cuisine',
#   'review_count': 3,
#   'rating': 5.0,
#   'price': 'None',
#   'latitude': 40.714952303984546,
#   'longitude': -73.80781662208928},
#  {'name': 'Edo Asian Fusion',
#   'review_count': 95,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.606292381664,
#   'longitude': -73.9616475521669},
#  {'name': 'Poke City',
#   'review_count': 64,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.691302,
#   'longitude': -73.991001},
#  {'name': '66S Fusion',
#   'review_count': 91,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.6977600194066,
#   'longitude': -73.9715740687866},
#  {'name': 'Hiro Sushi',
#   'review_count': 152,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.80912724768693,
#   'longitude': -74.11933642446526},
#  {'name': 'Fjord Fish Market',
#   'review_count': 17,
#   'rating': 4.5,
#   'price': 'None',
#   'latitude': 40.674733,
#   'longitude': -73.981415},
#  {'name': 'Sushi Jin',
#   'review_count': 41,
#   'rating': 5.0,
#   'price': 'None',
#   'latitude': 40.776032,
#   'longitude': -73.951988},
#  {'name': 'Sakura',
#   'review_count': 121,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.659767,
#   'longitude': -73.840307},
#  {'name': 'Mizu Sushi',
#   'review_count': 178,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7133185,
#   'longitude': -73.9618969},
#  {'name': 'Aji Sushi House',
#   'review_count': 466,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7742004394531,
#   'longitude': -73.9079513549805},
#  {'name': 'Sushi House 21',
#   'review_count': 136,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72705,
#   'longitude': -74.16002}]

# %%
# Replace None with appropriate code

# Import the library
import folium 

# Set up center latitude and longitude
center_lat = 40.650002
center_long = -73.949997

# Initialize map with center lat and long
yelp_map = folium.Map([center_lat, center_long], zoom_start=12)

# Adjust this limit to see more or fewer businesses
limit=100

for business in full_dataset[:limit]:
    # Extract information about business
    lat = business['latitude']
    long = business['longitude']
    name = business['name']
    rating = business['rating']
    price = business['price']
    details = "{}\nPrice: {} Rating:{}".format(name,price,rating)
    
    # Create popup with relevant details
    popup_text = "Name: {}, Rating: {}, Price: {}, Latitude: {}, Longitude: {}".format(name, rating, price, lat, long)
    popup = folium.Popup(popup_text, parse_html=True)
    
    # Create marker with relevant lat/long and popup
    marker = folium.Marker(location=[lat, long], popup=popup)
    
    marker.add_to(yelp_map)
    
yelp_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Summary
#
# Nice work! In this lab, you've made multiple API calls to Yelp in order to paginate through a results set, performing some basic exploratory analysis and then creating a nice interactive map to display the results using Folium! Well done!
